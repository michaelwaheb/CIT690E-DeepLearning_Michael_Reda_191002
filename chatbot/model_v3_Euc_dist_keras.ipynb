# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelwaheb/CIT690E-DeepLearning_Michael_Reda_191002/blob/main/chatbot/model_v3_Euc_dist_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --user -U nltk
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stops = set(stopwords.words('english'))
# Out:
# Requirement already satisfied: nltk in /root/.local/lib/python3.7/site-packages (3.6.7)
# Requirement already satisfied: regex>=2021.8.3 in /root/.local/lib/python3.7/site-packages (from nltk) (2022.1.18)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.62.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from keras import backend as K
from keras.layers import Layer
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import itertools

'''
This configuration file provides a series of predefined functions
'''


# ------------------custom function------------------ #

def text_to_word_list(text):  # 文本分词
    text = str(text)
    text = text.lower()
    # Text cleaning rules for English text
    import re
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)

    text = text.split()

    return text

def make_w2v_embeddings(flag, word2vec, df, embedding_dim):  # 将词转化为词向量
    vocabs = {}  # 词序号
    vocabs_count = 0  # 词个数计数器

    vocabs_not_w2v = {}  # 无法用词向量表示的词
    vocabs_not_w2v_count = 0  # Word count that cannot be represented by word vectors

    # 停用词
    # stops = set(open('data/stopwords.txt').read().strip().split('\n'))

    for index, row in df.iterrows():
        # 打印处理进度
        if index != 0 and index % 1000 == 0:
            print(str(index) + " sentences embedded.")

        for question in ['question1', 'question2']:
            q2n = []  # q2n -> question to numbers representation
            words = text_to_word_list(row[question])

            for word in words:
                # if word in stops:  # remove stop words
                # continue
                # The word of OOV is put into a dictionary that cannot be represented by a word vector, and the value is 1
                if word not in word2vec and word not in vocabs_not_w2v:  
                    vocabs_not_w2v_count += 1
                    vocabs_not_w2v[word] = 1   
                if word not in vocabs:  # Non-OOV words, extract the corresponding id
                    vocabs_count += 1
                    vocabs[word] = vocabs_count
                    q2n.append(vocabs_count)
                else:
                    q2n.append(vocabs[word])
            df.at[index, question + '_n'] = q2n

    embeddings = 1 * np.random.randn(len(vocabs) + 1, embedding_dim)  # 随机初始化一个形状为[全部词个数，词向量维度]的矩阵
    '''
    词1 [a1, a2, a3, ..., a60]
    词2 [b1, b2, b3, ..., b60]
    词3 [c1, c2, c3, ..., c60]
    '''
    embeddings[0] = 0  # 第一行用0填充，因为不存在index为0的词

    for index in vocabs:
        vocab_word = vocabs[index]
        if vocab_word in word2vec:
            embeddings[index] = word2vec[vocab_word]
    del word2vec

    return df, embeddings


def split_and_zero_padding(df, max_seq_length):  # 调整tokens长度

    # 训练集矩阵转换成字典
    X = {'left': df['question1_n'], 'right': df['question2_n']}

    # 调整到规定长度
    for dataset, side in itertools.product([X], ['left', 'right']):
        dataset[side] = pad_sequences(dataset[side], padding='pre', truncating='post', maxlen=max_seq_length)

    return dataset


class ManDist(Layer):  # 封装成keras层的曼哈顿距离计算

    # 初始化ManDist层，此时不需要任何参数输入
    def __init__(self, **kwargs):
        self.result = None
        super(ManDist, self).__init__(**kwargs)

    # Automatically build ManDist layer
    def build(self, input_shape):
        super(ManDist, self).build(input_shape)

    # Calculate Manhattan distance

    def call(self, x, **kwargs):
        self.result = K.exp(-K.sum(K.abs(x[0] - x[1]), axis=1, keepdims=True))
        return self.result

    # return result
    def compute_output_shape(self, input_shape):
        return K.int_shape(self.result)

class Euc_dist_keras(Layer):  # 封装成keras层的曼哈顿距离计算

    # 初始化ManDist层，此时不需要任何参数输入
    def __init__(self, **kwargs):
        self.result = None
        super(Euc_dist_keras, self).__init__(**kwargs)

    # Automatically build ManDist layer
    def build(self, input_shape):
        super(Euc_dist_keras, self).build(input_shape)

    # Calculate Manhattan distance

    def call(self, x, **kwargs):
        self.result = K.sqrt(K.sum(K.square(K.abs(x[0] - x[1])), axis=-1, keepdims=True))
        return self.result

    # return result
    def compute_output_shape(self, input_shape):
        return K.int_shape(self.result)

# %%
# Basic package
from time import time
import pandas as pd
from sklearn.model_selection import train_test_split
import keras
from gensim.models import KeyedVectors
from keras.models import Model
from keras.layers import Input, Embedding, LSTM, Dense, Flatten, Activation, RepeatVector, Permute, Lambda, \
    Bidirectional, TimeDistributed, Dropout, Conv1D, GlobalMaxPool1D
from keras.layers.merge import multiply, concatenate
import keras.backend as K
from tensorflow.keras.optimizers import Adam

# %%
# !pip install wget

import wget
url = 'https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz'
filename = wget.download(url)
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (3.2)

# %%
#! pip install kaggle
#! mkdir -p ~/.kaggle
#! cp kaggle.json ~/.kaggle/
#! chmod 600 ~/.kaggle/kaggle.json
#! kaggle competitions download quora-question-pairs -f train.csv.zip
#! kaggle competitions download quora-question-pairs -f test.csv.zip

# %%
#! unzip -o test.csv.zip
#! unzip -o train.csv.zip

# %%
# ------------------Preloading------------------ #

# Chinese and English training options, English training set is used by default
TRAIN_CSV = './train.csv'
flag = 'en'
embedding_path = 'GoogleNews-vectors-negative300.bin.gz'
embedding_dim = 300
max_seq_length = 32
savepath = './en_ameseLSTM.h5'

# %%
# Whether to enable pre-trained word vectors, use randomly initialized word vectors by default
# Load word vectors
print("Loading word2vec model(it may takes 2-3 mins) ...")
embedding_dict = KeyedVectors.load_word2vec_format(embedding_path, binary=True)
# Out:
# Loading word2vec model(it may takes 2-3 mins) ...

# %%
# Read and load the training set
train_df = pd.read_csv(TRAIN_CSV)
for q in ['question1', 'question2']:
    train_df[q + '_n'] = train_df[q]

# %%
# Vectorize the training set words
train_df, embeddings = make_w2v_embeddings(flag, embedding_dict, train_df, embedding_dim=embedding_dim)
# Out:
# 1000 sentences embedded.
# 2000 sentences embedded.
# 3000 sentences embedded.
# 4000 sentences embedded.
# 5000 sentences embedded.
# 6000 sentences embedded.
# 7000 sentences embedded.
# 8000 sentences embedded.
# 9000 sentences embedded.

# %%
for col in ['question1','question2']:
   # find indices, keep="all" means keep all occurrences. 
   idxs = train_df[col].astype(str).str.len().nlargest(
       1, keep="all"
   ).index
   # get values.
   values = train_df.loc[idxs, col]
   print('col : ',col, values)
# Out:
# col :  question1 862     I live with my mom and we are always arguing a...
# 1294    I live with my mom and we are always arguing a...
# 1320    A friend of mine is having a thyroid problem (...
# 1691    I am a 2014 medical graduate from India. I hav...
# 3009    I want to build an application for feature pho...
# 4730    I am an accountant and I want to change career...
# 5173    What's the difference between a "builder" and ...
# 5335    My boyfriend is very soft spoken.He can't hurt...
# 7229    I extracted 4 molar teeth because the dentist ...
# 7367    My friend while working was met with an accide...
# 7368    My friend while working was met with an accide...
# 8057    I asked my sisters to join a degree (BscIT) wh...
# Name: question1, dtype: object
# col :  question2 7821    I am working toward being a doctor and don��t ...
# 7822    I am working toward being a doctor and don��t ...
# Name: question2, dtype: object

# %%
for col in ['question1_n','question2_n']:
   # find indices, keep="all" means keep all occurrences. 
   idxs = train_df[col].astype(str).str.len().nlargest(
       1, keep="all"
   ).index
   # get values.
   values = train_df.loc[idxs, col]
   print('col : ',col, values)
# Out:
# col :  question1_n 862     [19, 89, 8, 21, 2854, 43, 115, 2, 1135, 2855, ...
# 1294    [19, 89, 8, 21, 2854, 43, 115, 2, 1135, 2855, ...
# Name: question1_n, dtype: object
# col :  question2_n 481    [1960, 1164, 1961, 354, 1962, 354, 1963, 1964,...
# 482    [1960, 1164, 1961, 354, 1962, 354, 1963, 1964,...
# Name: question2_n, dtype: object

# %%
# max_seq_length_in_dataset
max_seq_length_in_dataset = max(train_df.question1_n.map(lambda x: len(x)).max(),
                     train_df.question2_n.map(lambda x: len(x)).max())
print("max_seq_length_in_dataset : ",max_seq_length_in_dataset)
# Out:
# max_seq_length_in_dataset :  65

# %%
train_df.head()
# Out:
#    id  ...                                        question2_n
# 0  31  ...       [17, 18, 19, 20, 21, 10, 22, 23, 13, 24, 16]
# 1  50  ...            [17, 25, 26, 27, 33, 34, 6, 29, 30, 31]
# 2  50  ...            [17, 25, 26, 27, 33, 34, 6, 29, 30, 31]
# 3  58  ...  [19, 40, 41, 21, 39, 42, 52, 21, 46, 47, 17, 1...
# 4  61  ...  [1, 64, 9, 58, 59, 60, 15, 61, 17, 65, 54, 66,...
#
# [5 rows x 8 columns]

# %% [markdown]
# Take the training data from:
# question1   question2   is_duplicate
# borrow Repayment Information Borrow Repayment Date 0
# become:
#
# question1 question2 is_duplicate question1_n question2_n
# Borrow repayment information Borrow repayment date 0 Borrow repayment information Borrow repayment date
#
# After becoming id:
# question1 question2 is_duplicate question1_n question2_n
# Borrow repayment information Borrow repayment date 0 [31, 639] [31, 255]

# %%
# Split training set
X = train_df[['question1_n', 'question2_n']]
Y = train_df['is_duplicate']
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.2)

X_train = split_and_zero_padding(X_train, max_seq_length)
X_validation = split_and_zero_padding(X_validation, max_seq_length)

# %%
# Convert labels to numbers
Y_train = Y_train.values
Y_validation = Y_validation.values

# %%
# Confirm that the data is prepared and correct
print("X_train['left'].shape" , X_train['left'].shape)
print("X_train['right'].shape" , X_train['left'].shape)
print("len(X_train['left'])" , len(X_train['left']))
print("len(Y_train)" , len(Y_train))

assert X_train['left'].shape == X_train['right'].shape
assert len(X_train['left']) == len(Y_train)
# Out:
# X_train['left'].shape (7998, 32)
# X_train['right'].shape (7998, 32)
# len(X_train['left']) 7998
# len(Y_train) 7998

# %%
print(Y_validation)
# Out:
# [1 0 0 ... 0 1 0]

# %% [markdown]
# # -----------------base function------------------ #

# %%
def shared_model(_input):
    # word vectorization
    embedded = Embedding(len(embeddings), embedding_dim, weights=[embeddings], input_shape=(max_seq_length,),
                         trainable=False)(_input)

    # multilayerBi-LSTM
    activations = Bidirectional(LSTM(n_hidden, return_sequences=True), merge_mode='concat')(embedded)
    activations = Bidirectional(LSTM(n_hidden, return_sequences=True), merge_mode='concat')(activations)

    # dropout
    activations = Dropout(0.5)(activations)

    # Attention
    attention = TimeDistributed(Dense(1, activation='tanh'))(activations)
    attention = Flatten()(attention)
    attention = Activation('softmax')(attention)
    attention = RepeatVector(n_hidden * 2)(attention)
    attention = Permute([2, 1])(attention)
    sent_representation = multiply([activations, attention])
    sent_representation = Lambda(lambda xin: K.sum(xin, axis=1))(sent_representation)

    # dropout
    sent_representation = Dropout(0.5)(sent_representation)

    return sent_representation

# %%
if __name__ == '__main__':

    # Hyperparameter
    batch_size = 64
    n_epoch = 6
    n_hidden = 100

    left_input = Input(shape=(max_seq_length,), dtype='float32')
    right_input = Input(shape=(max_seq_length,), dtype='float32')

    left_sen_representation = shared_model(left_input)
    right_sen_representation = shared_model(right_input)

    # The Manhattan distance is introduced, and the original 
    #vector on the obtained transformation concat is 
    #then subjected to a non-linear transformation 
    #through a multi-layer DNN, and the sigmoid obtains the similarity
    
    # I did not use the Mahalanobis distance mentioned 
    #in https://zhuanlan.zhihu.com/p/31638132. 
    #I tried Manhattan distance, point product and cos, 
    #and Manhattan is the best.

    Euc_dist = Euc_dist_keras()([left_sen_representation, right_sen_representation])
    sen_representation = concatenate([left_sen_representation, right_sen_representation, Euc_dist])
    similarity = Dense(1, activation='sigmoid')(Dense(2)(Dense(4)(Dense(16)(sen_representation))))
    model = Model(inputs=[left_input, right_input], outputs=[similarity])

    model.compile(loss='mean_squared_error', optimizer= Adam(), metrics=['accuracy'])
    model.summary()

    training_start_time = time()
    malstm_trained = model.fit([X_train['left'], X_train['right']], Y_train,
                               batch_size=batch_size, epochs=n_epoch,
                               validation_data=([X_validation['left'], X_validation['right']], Y_validation))
    training_end_time = time()
    print("Training time finished.\n%d epochs in %12.2f" % (n_epoch, training_end_time - training_start_time))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32)]         0           []
#
#  input_2 (InputLayer)           [(None, 32)]         0           []
#
#  embedding (Embedding)          (None, 32, 300)      3516600     ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, 32, 300)      3516600     ['input_2[0][0]']
#
#  bidirectional (Bidirectional)  (None, 32, 200)      320800      ['embedding[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 32, 200)     320800      ['embedding_1[0][0]']
#  )
#
#  bidirectional_1 (Bidirectional  (None, 32, 200)     240800      ['bidirectional[0][0]']
#  )
#
#  bidirectional_3 (Bidirectional  (None, 32, 200)     240800      ['bidirectional_2[0][0]']
#  )
#
#  dropout (Dropout)              (None, 32, 200)      0           ['bidirectional_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 200)      0           ['bidirectional_3[0][0]']
#
#  time_distributed (TimeDistribu  (None, 32, 1)       201         ['dropout[0][0]']
#  ted)
#
#  time_distributed_1 (TimeDistri  (None, 32, 1)       201         ['dropout_2[0][0]']
#  buted)
#
#  flatten (Flatten)              (None, 32)           0           ['time_distributed[0][0]']
#
#  flatten_1 (Flatten)            (None, 32)           0           ['time_distributed_1[0][0]']
#
#  activation (Activation)        (None, 32)           0           ['flatten[0][0]']
#
#  activation_1 (Activation)      (None, 32)           0           ['flatten_1[0][0]']
#
#  repeat_vector (RepeatVector)   (None, 200, 32)      0           ['activation[0][0]']
#
#  repeat_vector_1 (RepeatVector)  (None, 200, 32)     0           ['activation_1[0][0]']
#
#  permute (Permute)              (None, 32, 200)      0           ['repeat_vector[0][0]']
#
#  permute_1 (Permute)            (None, 32, 200)      0           ['repeat_vector_1[0][0]']
#
#  multiply (Multiply)            (None, 32, 200)      0           ['dropout[0][0]',
#                                                                   'permute[0][0]']
#
#  multiply_1 (Multiply)          (None, 32, 200)      0           ['dropout_2[0][0]',
#                                                                   'permute_1[0][0]']
#
#  lambda (Lambda)                (None, 200)          0           ['multiply[0][0]']
#
#  lambda_1 (Lambda)              (None, 200)          0           ['multiply_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 200)          0           ['lambda[0][0]']
#
#  dropout_3 (Dropout)            (None, 200)          0           ['lambda_1[0][0]']
#
#  euc_dist_keras (Euc_dist_keras  (None, 1)           0           ['dropout_1[0][0]',
#  )                                                                'dropout_3[0][0]']
#
#  concatenate (Concatenate)      (None, 401)          0           ['dropout_1[0][0]',
#                                                                   'dropout_3[0][0]',
#                                                                   'euc_dist_keras[0][0]']
#
#  dense_5 (Dense)                (None, 16)           6432        ['concatenate[0][0]']
#
#  dense_4 (Dense)                (None, 4)            68          ['dense_5[0][0]']
#
#  dense_3 (Dense)                (None, 2)            10          ['dense_4[0][0]']
#
#  dense_2 (Dense)                (None, 1)            3           ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 8,163,315
# Trainable params: 1,130,115
# Non-trainable params: 7,033,200
# __________________________________________________________________________________________________
# Epoch 1/6
# 125/125 [==============================] - 16s 43ms/step - loss: 0.1859 - accuracy: 0.7147 - val_loss: 0.1636 - val_accuracy: 0.7595
# Epoch 2/6
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1268 - accuracy: 0.8238 - val_loss: 0.1589 - val_accuracy: 0.7820
# Epoch 3/6
# 125/125 [==============================] - 3s 23ms/step - loss: 0.0847 - accuracy: 0.8896 - val_loss: 0.1459 - val_accuracy: 0.8035
# Epoch 4/6
# 125/125 [==============================] - 3s 23ms/step - loss: 0.0571 - accuracy: 0.9267 - val_loss: 0.1695 - val_accuracy: 0.7875
# Epoch 5/6
# 125/125 [==============================] - 3s 23ms/step - loss: 0.0415 - accuracy: 0.9495 - val_loss: 0.1366 - val_accuracy: 0.8325
# Epoch 6/6
# 125/125 [==============================] - 3s 23ms/step - loss: 0.0319 - accuracy: 0.9607 - val_loss: 0.1395 - val_accuracy: 0.8295
# Training time finished.
# 6 epochs in        30.72

# %%
# Plot accuracy
import matplotlib.pyplot as plt
#plt.subplot(211)
plt.plot(malstm_trained.history['accuracy'])
plt.plot(malstm_trained.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot loss
#plt.subplot(212)
plt.plot(malstm_trained.history['loss'])
plt.plot(malstm_trained.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

model.save(savepath)
print(str(malstm_trained.history['val_accuracy'][-1])[:6] + "(max: " + str(max(malstm_trained.history['val_accuracy']))[:6] + ")")
print("Done.")
# Out:
# 0.8295(max: 0.8324)
# Done.
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
import json
def readJson(filename):
  with open(filename, 'r') as file:
    intents = json.load(file)
    return intents

# %%
icliniqQAs = readJson('icliniqQAs.json')
webmdQAs = readJson('webmdQAs.json')
questionDoctorQAs = readJson('questionDoctorQAs.json')
ehealthforumQAs = readJson('ehealthforumQAs.json')

all_medical_list = icliniqQAs+webmdQAs+questionDoctorQAs+ehealthforumQAs
print(len(icliniqQAs)+len(webmdQAs)+len(questionDoctorQAs)+len(ehealthforumQAs))
print(len(all_medical_list))
type(all_medical_list)

all_medical_list[0]
# Out:
# 29752
# 29752
# {'answer': 'from your description it appears that you may have anterior knee pain which sometimes presents as pain at the back of the knee. the second possibility is that you have over done your exercise and hamstrings are sore and the lower end of the knee cap is inflamed. either way you should rest and ice the area of pain and give it time. i suggest you add nsaids (nonsteroidal anti-inflammatory drugs) for a week for an additional anti-inflammatory action. for further information consult an orthopaedician and traumatologist online --> <link>',
#  'question': 'is it fine to exercise with knee pain?',
#  'question_text': '\r\n\r\n\r\n\t\t\t\t\tHi doctor,\nI am a 24 year old female. My height is 5\'5" and weight is 58 kg. I am a cyclist and, to a lesser extent, a runner. For the past one\xa0week, I have been getting pain in the back of my left knee. It hurts when I walk and not just doing sport. It is the movement of pushing off from the ground that makes it hurt, and when I straighten my leg to full extension.\xa0Is it fine to continue with exercise?\t\t\t\t',
#  'tags': ['exercises'],
#  'url': 'https://www.icliniq.com/qa/knee-pain/is-it-fine-to-exercise-with-knee-pain'}

# %%
import pandas as pd
all_medical_df = pd.DataFrame.from_dict(all_medical_list)
all_medical_df
# Out:
#                                                   answer  ... answer_author
# 0      from your description it appears that you may ...  ...           NaN
# 1      depression anxiety restlessness and panic atta...  ...           NaN
# 2      patients with hypothyroidism usually gain weig...  ...           NaN
# 3      fenugreek seed cannot affect your fertility do...  ...           NaN
# 4      your problem is a characteristic of cholinergi...  ...           NaN
# ...                                                  ...  ...           ...
# 29747  what your boyfriend seems to be having is bipo...  ...           NaN
# 29748  depression is common with any comorbid illness...  ...           NaN
# 29749  in bipolar disorder sometimes there are mixed ...  ...           NaN
# 29750  hello. from your description here it seems you...  ...           NaN
# 29751  the description provided indicates that you mi...  ...           NaN
#
# [29752 rows x 6 columns]

# %%
all_medical_df.drop(columns=['question_text', 'url','answer_author'],inplace = True)
all_medical_df
# Out:
#                                                   answer  ...                                               tags
# 0      from your description it appears that you may ...  ...                                        [exercises]
# 1      depression anxiety restlessness and panic atta...  ...                                          [anxiety]
# 2      patients with hypothyroidism usually gain weig...  ...                                   [hypothyroidism]
# 3      fenugreek seed cannot affect your fertility do...  ...                                   [delayed period]
# 4      your problem is a characteristic of cholinergi...  ...                                   [levocetirizine]
# ...                                                  ...  ...                                                ...
# 29747  what your boyfriend seems to be having is bipo...  ...  [smoking pot, bipolar, smoking, abusive, bipol...
# 29748  depression is common with any comorbid illness...  ...                                         [dyslexia]
# 29749  in bipolar disorder sometimes there are mixed ...  ...  [bipolar, medication, bipolar help, anger help...
# 29750  hello. from your description here it seems you...  ...  [bipolar disorder, anxiety, bipolar, angry, an...
# 29751  the description provided indicates that you mi...  ...  [bipolar disorder, abruptly, bipolar, about bi...
#
# [29752 rows x 3 columns]

# %%
test_df = pd.DataFrame(all_medical_df["question"])
test_df.columns = ['question1']

test_df['question2']="i had high pressure?"
test_df
# Out:
#                                                question1             question2
# 0                 is it fine to exercise with knee pain?  i had high pressure?
# 1      suffering from anxiety restlessness and taking...  i had high pressure?
# 2       can a thyroid patient eat soybean and fenugreek?  i had high pressure?
# 3      i am not getting my periods after taking fenug...  i had high pressure?
# 4      kindly suggest me a therapy to overcome heat a...  i had high pressure?
# ...                                                  ...                   ...
# 29747  i belive my boyfriend is bipolar or has boderl...  i had high pressure?
# 29748  why do i feel so down when someone makes fun o...  i had high pressure?
# 29749  please help! my fiance is bipolar but will not...  i had high pressure?
# 29750  i constantly have bursts of anger for no reaso...  i had high pressure?
# 29751  hello i'm 20 years old and i've always seemed ...  i had high pressure?
#
# [29752 rows x 2 columns]

# %%
import pandas as pd

import tensorflow as tf


# File paths
#TEST_CSV = './data/test-20.csv'

# Load training set
#test_df = pd.read_csv(TEST_CSV)
for q in ['question1', 'question2']:
    test_df[q + '_n'] = test_df[q]

# Make word2vec embeddings
embedding_dim = 300
max_seq_length = 32
test_df, embeddings = make_w2v_embeddings(flag, embedding_dict, test_df, embedding_dim=embedding_dim)

# Split to dicts and append zero padding.
X_test = split_and_zero_padding(test_df, max_seq_length)

# Make sure everything is ok
assert X_test['left'].shape == X_test['right'].shape

# --

model = tf.keras.models.load_model('./en_ameseLSTM.h5', custom_objects={'Euc_dist_keras': Euc_dist_keras})
model.summary()

prediction = model.predict([X_test['left'], X_test['right']])
print(prediction)
# Out:
# 1000 sentences embedded.
# 2000 sentences embedded.
# 3000 sentences embedded.
# 4000 sentences embedded.
# 5000 sentences embedded.
# 6000 sentences embedded.
# 7000 sentences embedded.
# 8000 sentences embedded.
# 9000 sentences embedded.
# 10000 sentences embedded.
# 11000 sentences embedded.
# 12000 sentences embedded.
# 13000 sentences embedded.
# 14000 sentences embedded.
# 15000 sentences embedded.
# 16000 sentences embedded.
# 17000 sentences embedded.
# 18000 sentences embedded.
# 19000 sentences embedded.
# 20000 sentences embedded.
# 21000 sentences embedded.
# 22000 sentences embedded.
# 23000 sentences embedded.
# 24000 sentences embedded.
# 25000 sentences embedded.
# 26000 sentences embedded.
# 27000 sentences embedded.
# 28000 sentences embedded.
# 29000 sentences embedded.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32)]         0           []
#
#  input_2 (InputLayer)           [(None, 32)]         0           []
#
#  embedding (Embedding)          (None, 32, 300)      3516600     ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, 32, 300)      3516600     ['input_2[0][0]']
#
#  bidirectional (Bidirectional)  (None, 32, 200)      320800      ['embedding[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 32, 200)     320800      ['embedding_1[0][0]']
#  )
#
#  bidirectional_1 (Bidirectional  (None, 32, 200)     240800      ['bidirectional[0][0]']
#  )
#
#  bidirectional_3 (Bidirectional  (None, 32, 200)     240800      ['bidirectional_2[0][0]']
#  )
#
#  dropout (Dropout)              (None, 32, 200)      0           ['bidirectional_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 200)      0           ['bidirectional_3[0][0]']
#
#  time_distributed (TimeDistribu  (None, 32, 1)       201         ['dropout[0][0]']
#  ted)
#
#  time_distributed_1 (TimeDistri  (None, 32, 1)       201         ['dropout_2[0][0]']
#  buted)
#
#  flatten (Flatten)              (None, 32)           0           ['time_distributed[0][0]']
#
#  flatten_1 (Flatten)            (None, 32)           0           ['time_distributed_1[0][0]']
#
#  activation (Activation)        (None, 32)           0           ['flatten[0][0]']
#
#  activation_1 (Activation)      (None, 32)           0           ['flatten_1[0][0]']
#
#  repeat_vector (RepeatVector)   (None, 200, 32)      0           ['activation[0][0]']
#
#  repeat_vector_1 (RepeatVector)  (None, 200, 32)     0           ['activation_1[0][0]']
#
#  permute (Permute)              (None, 32, 200)      0           ['repeat_vector[0][0]']
#
#  permute_1 (Permute)            (None, 32, 200)      0           ['repeat_vector_1[0][0]']
#
#  multiply (Multiply)            (None, 32, 200)      0           ['dropout[0][0]',
#                                                                   'permute[0][0]']
#
#  multiply_1 (Multiply)          (None, 32, 200)      0           ['dropout_2[0][0]',
#                                                                   'permute_1[0][0]']
#
#  lambda (Lambda)                (None, 200)          0           ['multiply[0][0]']
#
#  lambda_1 (Lambda)              (None, 200)          0           ['multiply_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 200)          0           ['lambda[0][0]']
#
#  dropout_3 (Dropout)            (None, 200)          0           ['lambda_1[0][0]']
#
#  euc_dist_keras (Euc_dist_keras  (None, 1)           0           ['dropout_1[0][0]',
#  )                                                                'dropout_3[0][0]']
#
#  concatenate (Concatenate)      (None, 401)          0           ['dropout_1[0][0]',
#                                                                   'dropout_3[0][0]',
#                                                                   'euc_dist_keras[0][0]']
#
#  dense_5 (Dense)                (None, 16)           6432        ['concatenate[0][0]']
#
#  dense_4 (Dense)                (None, 4)            68          ['dense_5[0][0]']
#
#  dense_3 (Dense)                (None, 2)            10          ['dense_4[0][0]']
#
#  dense_2 (Dense)                (None, 1)            3           ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 8,163,315
# Trainable params: 1,130,115
# Non-trainable params: 7,033,200
# __________________________________________________________________________________________________
# [[3.7558019e-02]
#  [3.3241976e-04]
#  [2.2177377e-03]
#  ...
#  [1.2744541e-06]
#  [3.8894791e-06]
#  [1.0313714e-03]]

# %%
test_df.shape
# Out:
# (29752, 4)

# %%
prediction.shape
# Out:
# (29752, 1)

# %%
Eval = pd.DataFrame(columns= ['question1','question2','prediction'])
Eval['question1']= test_df['question1']
Eval['question2']=test_df['question2']
Eval['prediction']= prediction
Eval
# Out:
#                                                question1  ... prediction
# 0                 is it fine to exercise with knee pain?  ...   0.037558
# 1      suffering from anxiety restlessness and taking...  ...   0.000332
# 2       can a thyroid patient eat soybean and fenugreek?  ...   0.002218
# 3      i am not getting my periods after taking fenug...  ...   0.747723
# 4      kindly suggest me a therapy to overcome heat a...  ...   0.000253
# ...                                                  ...  ...        ...
# 29747  i belive my boyfriend is bipolar or has boderl...  ...   0.003489
# 29748  why do i feel so down when someone makes fun o...  ...   0.087429
# 29749  please help! my fiance is bipolar but will not...  ...   0.000001
# 29750  i constantly have bursts of anger for no reaso...  ...   0.000004
# 29751  hello i'm 20 years old and i've always seemed ...  ...   0.001031
#
# [29752 rows x 3 columns]

# %%
B_sorted = Eval.sort_values(["prediction"], ascending='false')
B_sorted.tail(10)
# Out:
#                                                question1  ... prediction
# 3      i am not getting my periods after taking fenug...  ...   0.747723
# 15281  how serious is prostatitis and can i resume no...  ...   0.761687
# 24769  i was told my ongoing chest pain is not cardia...  ...   0.779941
# 24768  i was told my ongoing chest pain is not cardia...  ...   0.779941
# 24767  i was told my ongoing chest pain is not cardia...  ...   0.779941
# 24766  i was told my ongoing chest pain is not cardia...  ...   0.779941
# 24771  i was told my ongoing chest pain is not cardia...  ...   0.779941
# 24770  i was told my ongoing chest pain is not cardia...  ...   0.779941
# 15632  i have or think i have parkinsons disease when...  ...   0.802429
# 20237  i have or think i have fertility problems when...  ...   0.848704
#
# [10 rows x 3 columns]

# %%
column = Eval["prediction"]
max_index = column.idxmax()
max_index
# Out:
# 20237

# %%
Eval.iloc[[max_index]]
# Out:
#                                                question1  ... prediction
# 20237  i have or think i have fertility problems when...  ...   0.848704
#
# [1 rows x 3 columns]

# %%
all_medical_df.iloc[[24766]]
# Out:
#                                                   answer  ...                                               tags
# 24766  hi my opinion your problem is stress related. ...  ...  [i experienced a nstemi ha i had two stents fi...
#
# [1 rows x 3 columns]

# %%
all_medical_df.shape
# Out:
# (29752, 3)
